# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
# Out:
# /Users/belinda/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
df = pd.read_csv('/Users/belinda/Desktop/DAC-Internal-Projects/dataset/updated_dataset.csv')

# %%
df.head()
# Out:
#         month        town flat_type block        street_name storey_range  \
# 0  2017-01-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model lease_commence_date     remaining_lease  \
# 0            44.0        Improved          1979-01-01  61 years 04 months
# 1            67.0  New Generation          1978-01-01  60 years 07 months
# 2            67.0  New Generation          1980-01-01  62 years 05 months
# 3            68.0  New Generation          1980-01-01   62 years 01 month
# 4            67.0  New Generation          1980-01-01  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# ...

# %%
df.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
#unique values for town
df['town'].unique()
# Out:
# array(['ang mo kio', 'bedok', 'bishan', 'bukit batok', 'bukit merah',
#        'bukit panjang', 'bukit timah', 'central area', 'choa chu kang',
#        'clementi', 'geylang', 'hougang', 'jurong east', 'jurong west',
#        'kallang/whampoa', 'marine parade', 'pasir ris', 'punggol',
#        'queenstown', 'sembawang', 'sengkang', 'serangoon', 'tampines',
#        'toa payoh', 'woodlands', 'yishun'], dtype=object)

# %%
#importing mrt dataset
mrt_df = pd.read_csv('/Users/belinda/Desktop/DAC-Internal-Projects/dataset/mrt_lrt_data.csv')

# %%
mrt_df['station_name'].unique()
# Out:
# array(['jurong east', 'bukit batok', 'bukit gombak', 'choa chu kang',
#        'yew tee', 'kranji', 'marsiling', 'woodlands', 'admiralty',
#        'sembawang', 'yishun', 'khatib', 'yio chu kang', 'ang mo kio',
#        'bishan', 'braddell', 'toa payoh', 'novena', 'newton', 'orchard',
#        'somerset', 'dhoby ghaut', 'city hall', 'raffles place',
#        'marina bay', 'marina south pier', 'tuas link', 'tuas west road',
#        'tuas crescent', 'gul circle', 'joo koon', 'pioneer', 'boon lay',
#        'lakeside', 'chinese garden', 'clementi', 'dover', 'buona vista',
#        'commonwealth', 'queenstown', 'redhill', 'tiong bahru',
#        'outram park', 'tanjong pagar', 'bugis', 'lavender', 'kallang',
#        'aljunied', 'paya lebar', 'eunos', 'kembangan', 'bedok',
#        'tanah merah', 'simei', 'tampines', 'pasir ris', 'expo',
#        'changi airport', 'harbourfront', 'chinatown', 'clarke quay',
#        'little india', 'farrer park', 'boon keng', 'potong pasir',
# ...

# %%
#converting town values to lowercase
df['town'] = df['town'].str.lower()
df.head()
# Out:
#         month        town flat_type block        street_name storey_range  \
# 0  2017-01-01  ang mo kio    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01-01  ang mo kio    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01-01  ang mo kio    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01-01  ang mo kio    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01-01  ang mo kio    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model lease_commence_date     remaining_lease  \
# 0            44.0        Improved          1979-01-01  61 years 04 months
# 1            67.0  New Generation          1978-01-01  60 years 07 months
# 2            67.0  New Generation          1980-01-01  62 years 05 months
# 3            68.0  New Generation          1980-01-01   62 years 01 month
# 4            67.0  New Generation          1980-01-01  62 years 05 months
#
#    resale_price                address
# ...

# %%
mrt_df.head()
# Out:
#     station_name type       lat         lng
# 0    jurong east  MRT  1.333207  103.742308
# 1    bukit batok  MRT  1.349069  103.749596
# 2   bukit gombak  MRT  1.359043  103.751863
# 3  choa chu kang  MRT  1.385417  103.744316
# 4        yew tee  MRT  1.397383  103.747523

# %%
#changing station_name to lowercase
mrt_df['station_name'] = mrt_df['station_name'].str.lower()
mrt_df.head()
# Out:
#     station_name type       lat         lng
# 0    jurong east  MRT  1.333207  103.742308
# 1    bukit batok  MRT  1.349069  103.749596
# 2   bukit gombak  MRT  1.359043  103.751863
# 3  choa chu kang  MRT  1.385417  103.744316
# 4        yew tee  MRT  1.397383  103.747523

# %%
#making address portion for df
df['address'] = df['block'] + " " + df['street_name']
df['address'].head()
df.head()
# Out:
#         month        town flat_type block        street_name storey_range  \
# 0  2017-01-01  ang mo kio    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01-01  ang mo kio    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01-01  ang mo kio    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01-01  ang mo kio    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01-01  ang mo kio    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model lease_commence_date     remaining_lease  \
# 0            44.0        Improved          1979-01-01  61 years 04 months
# 1            67.0  New Generation          1978-01-01  60 years 07 months
# 2            67.0  New Generation          1980-01-01  62 years 05 months
# 3            68.0  New Generation          1980-01-01   62 years 01 month
# 4            67.0  New Generation          1980-01-01  62 years 05 months
#
#    resale_price                address
# ...

# %%
df.to_csv('/Users/belinda/Desktop/DAC-Internal-Projects/dataset/address_added.csv', index=False)

# %%
#importing mrt dataset
mrt_df = pd.read_csv('/Users/belinda/Desktop/DAC-Internal-Projects/dataset/mrt_lrt_data.csv')

# %%
# # Merge HDB DataFrame with MRT DataFrame based on the MRT station name
# merged_df = pd.merge(df, mrt_df, left_on='town', right_on='station_name', how='left')
# merged_df.head()

# %%
# merged_df.isnull().sum()

# %%
# latitude = []
# longitude = []
# blk_no = []
# road_name = []
# postal_code = []
# address = []
# count = 0

# for row in range(len(address_list)):
#     query_address = address_list[row]
#     query_string='https://developers.onemap.sg/commonapi/search?searchVal='+str(query_address)+'&returnGeom=Y&getAddrDetails=Y&pageNum=1'
#     resp = requests.get(query_string)


#     data_geo_location=json.loads(resp.content)
#     if data_geo_location['found'] != 0:
#         latitude.append(data_geo_location['results'][0]['LATITUDE'])
#         longitude.append(data_geo_location['results'][0]['LONGITUDE'])
#         blk_no.append(data_geo_location['results'][0]['BLK_NO'])
#         road_name.append(data_geo_location['results'][0]['ROAD_NAME'])
#         postal_code.append(data_geo_location['results'][0]['POSTAL'])
#         address.append(query_address)
#         print (str(query_address) + " ,Lat: " + data_geo_location['results'][0]['LATITUDE'] + " Long: " + data_geo_location['results'][0]['LONGITUDE'])
#     else:
#         print ("No Results")

# %%
# #chatgpt on how to use onemap api
# def get_lat_lon(block, street_name):
#     # Replace with your API endpoint
#     base_url = "https://developers.onemap.sg/commonapi/search"
    
#     # Construct query
#     query = f"{block} {street_name}"
#     params = {
#         'searchVal': query,
#         'returnGeom': 'Y',
#         'getAddrDetails': 'Y',
#         'pageNum': 1
#     }
    
#     # Send request to OneMap API
#     response = requests.get(base_url, params=params)
    
#     # Parse the response
#     if response.status_code == 200:
#         results = response.json().get('results', [])
#         if results:
#             return float(results[0]['LATITUDE']), float(results[0]['LONGITUDE'])
#         else:
#             return None, None
#     else:
#         return None, None
    
# # Apply the function to each row
# df['latitude'], df['longitude'] = zip(*df.apply(lambda x: get_lat_lon(x['block'], x['street_name']), axis=1))

# print(df)

# %%
# import requests
# import time

# def make_request_with_retry(url, params, retries=3, delay=5):
#     for i in range(retries):
#         try:
#             response = requests.get(url, params=params)
#             response.raise_for_status()  # Raise an exception for bad HTTP responses
#             return response
#         except (requests.ConnectionError, requests.Timeout, requests.RequestException) as e:
#             print(f"Attempt {i+1} failed: {e}")
#             if i < retries - 1:
#                 print(f"Retrying in {delay} seconds...")
#                 time.sleep(delay)
#             else:
#                 print("Max retries exceeded.")
#                 return None

# # Example usage
# base_url = "https://developers.onemap.sg/commonapi/search"
# params = {'searchVal': '406 ANG MO KIO AVE 10', 'returnGeom': 'Y', 'getAddrDetails': 'Y', 'pageNum': 1}
# response = make_request_with_retry(base_url, params)
# if response:
#     print(response.json())

# %%
# def get_latlong(address):
#     """
#     Retrieve latitude and longitude for a given address using OneMap SG API
    
#     Parameters:
#     address (str): Address to geocode
    
#     Returns:
#     tuple: (latitude, longitude) or (None, None) if geocoding fails
#     """
#     base_url = "https://www.onemap.gov.sg/api/common/elastic/search"
    
#     params = {
#         "searchVal": address,
#         "returnGeom": "Y",
#         "getAddrDetails": "Y"
#     }
    
#     try:
#         response = requests.get(base_url, params=params)
        
#         if response.status_code == 200:
#             data = response.json()
            
#             if data.get('results') and len(data['results']) > 0:
#                 first_result = data['results'][0]
#                 return (
#                     float(first_result.get('LATITUDE', None)),
#                     float(first_result.get('LONGITUDE', None))
#                 )
        
#         return None, None
    
#     except Exception as e:
#         print(f"Error geocoding address: {e}")
#         return None, None

# # Create a DataFrame with a single address
# df = pd.DataFrame({
#     'address': ['1 Raffles Place']
# })

# # Get latitude and longitude
# df[['latitude', 'longitude']] = df['address'].apply(lambda x: pd.Series(get_latlong(x)))

# print(df)

# %%
# #too slow with rate limiting
# import requests
# import pandas as pd
# import time
# from tqdm import tqdm

# def get_latlong(address):
#     """
#     Retrieve latitude and longitude for a given address using OneMap SG API
    
#     Parameters:
#     address (str): Address to geocode
    
#     Returns:
#     tuple: (latitude, longitude) or (None, None) if geocoding fails
#     """
#     base_url = "https://www.onemap.gov.sg/api/common/elastic/search"
    
#     params = {
#         "searchVal": address,
#         "returnGeom": "Y",
#         "getAddrDetails": "Y"
#     }
    
#     try:
#         response = requests.get(base_url, params=params)
        
#         if response.status_code == 200:
#             data = response.json()
            
#             if data.get('results') and len(data['results']) > 0:
#                 first_result = data['results'][0]
#                 return (
#                     float(first_result.get('LATITUDE', None)),
#                     float(first_result.get('LONGITUDE', None))
#                 )
        
#         return None, None
    
#     except Exception as e:
#         print(f"Error geocoding address '{address}': {e}")
#         return None, None

# def geocode_large_dataframe(df, address_column, max_requests_per_minute=30):
#     """
#     Geocode a large DataFrame with rate limiting and progress tracking
    
#     Parameters:
#     df (pd.DataFrame): Input DataFrame
#     address_column (str): Name of the column containing addresses
#     max_requests_per_minute (int): Maximum number of API requests per minute
    
#     Returns:
#     pd.DataFrame: DataFrame with added latitude and longitude columns
#     """
#     # Create a copy of the DataFrame to avoid modifying the original
#     geocoded_df = df.copy()
    
#     # Calculate delay between requests to respect rate limits
#     delay = 60 / max_requests_per_minute
    
#     # Prepare results lists
#     latitudes = []
#     longitudes = []
    
#     # Progress bar for tracking
#     tqdm.pandas(desc="Geocoding Addresses")
    
#     # Process addresses with rate limiting and progress tracking
#     for address in tqdm(geocoded_df[address_column], desc="Geocoding"):
#         # Attempt to get lat/long
#         lat, lon = get_latlong(str(address))
        
#         # Store results
#         latitudes.append(lat)
#         longitudes.append(lon)
        
#         # Pause to respect rate limits
#         time.sleep(delay)
    
#     # Add latitude and longitude columns
#     geocoded_df['latitude'] = latitudes
#     geocoded_df['longitude'] = longitudes
    
#     return geocoded_df

# # Geocode the large DataFrame
# result_df = geocode_large_dataframe(df, 'address')

# # Save results to CSV (optional)
# result_df.to_csv('geocoded_addresses.csv', index=False)

# # Display some statistics
# print("\nGeocoding Complete:")
# print(f"Total Addresses: {len(result_df)}")
# print(f"Successfully Geocoded: {result_df['latitude'].notna().sum()}")
# print(f"Failed Geocoding: {result_df['latitude'].isna().sum()}")

# %%
# #still too slow
# import requests
# import pandas as pd
# from tqdm import tqdm

# def get_latlong(address):
#     """
#     Retrieve latitude and longitude for a given address using OneMap SG API  
    
#     Parameters:
#     address (str): Address to geocode
    
#     Returns:
#     tuple: (latitude, longitude) or (None, None) if geocoding fails
#     """
#     base_url = "https://www.onemap.gov.sg/api/common/elastic/search"
    
#     params = {
#         "searchVal": address,
#         "returnGeom": "Y",
#         "getAddrDetails": "Y"
#     }
    
#     try:
#         response = requests.get(base_url, params=params)
        
#         if response.status_code == 200:
#             data = response.json()
            
#             if data.get('results') and len(data['results']) > 0:
#                 first_result = data['results'][0]
#                 return (
#                     float(first_result.get('LATITUDE', None)),
#                     float(first_result.get('LONGITUDE', None))
#                 )
        
#         return None, None
    
#     except Exception as e:
#         print(f"Error geocoding address '{address}': {e}")
#         return None, None

# def geocode_large_dataframe(df, address_column):
#     """
#     Geocode a large DataFrame without rate limiting, but with progress tracking
    
#     Parameters:
#     df (pd.DataFrame): Input DataFrame
#     address_column (str): Name of the column containing addresses
    
#     Returns:
#     pd.DataFrame: DataFrame with added latitude and longitude columns
#     """
#     # Create a copy of the DataFrame to avoid modifying the original
#     geocoded_df = df.copy()
    
#     # Prepare results lists
#     latitudes = []
#     longitudes = []
    
#     # Progress bar for tracking
#     tqdm.pandas(desc="Geocoding Addresses")
    
#     # Process addresses without rate limiting
#     for address in tqdm(geocoded_df[address_column], desc="Geocoding"):
#         # Attempt to get lat/long
#         lat, lon = get_latlong(str(address))
        
#         # Store results
#         latitudes.append(lat)
#         longitudes.append(lon)
    
#     # Add latitude and longitude columns
#     geocoded_df['latitude'] = latitudes
#     geocoded_df['longitude'] = longitudes
    
#     return geocoded_df

# # Geocode the large DataFrame
# result_df = geocode_large_dataframe(df, 'address')

# # Save results to CSV (optional)
# result_df.to_csv('geocoded_addresses.csv', index=False)

# # Display some statistics
# print("\nGeocoding Complete:")
# print(f"Total Addresses: {len(result_df)}")
# print(f"Successfully Geocoded: {result_df['latitude'].notna().sum()}")
# print(f"Failed Geocoding: {result_df['latitude'].isna().sum()}")

# %%
address_list = df['address'].unique()
address_list
# Out:
# array(['406 ANG MO KIO AVE 10', '108 ANG MO KIO AVE 4',
#        '602 ANG MO KIO AVE 5', ..., '610B TAMPINES NTH DR 1',
#        '609C TAMPINES NTH DR 1', '608C TAMPINES NTH DR 1'], dtype=object)

# %%
latitude = []
longitude = []
blk_no = []
road_name = []
postal_code = []
address = []
count = 0

for row in range(len(address_list)):
    query_address = address_list[row]
    query_string='https://www.onemap.gov.sg/api/common/elastic/search?searchVal='+str(query_address)+'&returnGeom=Y&getAddrDetails=Y&pageNum=1'
    resp = requests.get(query_string)


    data_geo_location=json.loads(resp.content)
    if data_geo_location['found'] != 0:
        latitude.append(data_geo_location['results'][0]['LATITUDE'])
        longitude.append(data_geo_location['results'][0]['LONGITUDE'])
        blk_no.append(data_geo_location['results'][0]['BLK_NO'])
        road_name.append(data_geo_location['results'][0]['ROAD_NAME'])
        postal_code.append(data_geo_location['results'][0]['POSTAL'])
        address.append(query_address)
        print (str(query_address) + " ,Lat: " + data_geo_location['results'][0]['LATITUDE'] + " Long: " + data_geo_location['results'][0]['LONGITUDE'])
    else:
        print ("No Results")
# Out:
# 406 ANG MO KIO AVE 10 ,Lat: 1.36200453938712 Long: 103.853879910407
# 108 ANG MO KIO AVE 4 ,Lat: 1.37096635222625 Long: 103.838201940326
# 602 ANG MO KIO AVE 5 ,Lat: 1.38070883044887 Long: 103.835368226602
# 465 ANG MO KIO AVE 10 ,Lat: 1.3662010408294 Long: 103.857200967235
# 601 ANG MO KIO AVE 5 ,Lat: 1.38104134784496 Long: 103.835131744823
# 150 ANG MO KIO AVE 5 ,Lat: 1.37680678506745 Long: 103.842017962576
# 447 ANG MO KIO AVE 10 ,Lat: 1.36747901420817 Long: 103.855967139125
# 218 ANG MO KIO AVE 1 ,Lat: 1.36511908595886 Long: 103.841742478489
# 571 ANG MO KIO AVE 3 ,Lat: 1.37005501296043 Long: 103.85488055876
# 534 ANG MO KIO AVE 10 ,Lat: 1.37405846295585 Long: 103.854168170426
# 233 ANG MO KIO AVE 3 ,Lat: 1.36754924977907 Long: 103.836740628478
# 235 ANG MO KIO AVE 3 ,Lat: 1.36682360872342 Long: 103.83649123351
# 219 ANG MO KIO AVE 1 ,Lat: 1.36598198004505 Long: 103.840654039612
# 536 ANG MO KIO AVE 10 ,Lat: 1.37447378519738 Long: 103.854100515826
# ...
